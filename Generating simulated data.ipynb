# %%
import numpy as np
from matplotlib import pyplot as plt

# %%
temp = np.random.uniform(2000,5000,100)
#print(temp)
T_x = np.zeros((100,300))
amplitudes = np.zeros((100,20))
channels = np.zeros((100,20), dtype = int)
T_y = np.zeros((100,300))
RFI = np.zeros_like(T_x)
for i in range(100):
    T_x[i] = temp[i]* (freq/50)**(-2.5)
    T_y[i] = np.copy(T_x[i])
    amplitudes[i] = np.random.rand(20)*500
    channels[i] = np.random.randint(0,300,20,dtype = np.uint16)
    T_y[i,channels[i]] = T_x[i,channels[i]] + amplitudes[i]
    plt.plot(freq, T_x[i] + 100*i)
    plt.plot(freq,T_y[i] + 100*i)
np.savez('C:/Users/msonawan/Documents/Data/Data_file_100',spectra=T_x,RFI_channels=channels,RFI_amps=amplitudes)

# %%
freq = np.linspace(50,100,300)
T_x = 4826.42* (freq/50)**(-2.5)
T_y = np.copy(T_x)
T_x[channels] = T_x[channels] + amplitudes
spectra = 
'''
T_x[9] = T_x[9] +569
T_x[18] = T_x[18] - 100
T_x[25] = T_x[25] - 200
T_x[35] = T_x[35] + 300
T_x[55] = T_x[55] + 550
T_x[62] = T_x[62] + 150
T_x[75] = T_x[75] + 250
T_x[84] = T_x[84] + 350
T_x[93] = T_x[93] - 250
T_x[110] = T_x[110] + 600
T_x[126] = T_x[126] + 275
T_x[140] = T_x[140] - 450
T_x[151] = T_x[151] - 468
T_x[169] = T_x[169] + 467
T_x[172] = T_x[172] + 837
T_x[189] = T_x[189] - 446
T_x[195] = T_x[195] + 761
T_x[203] = T_x[203] - 479
T_x[216] = T_x[216] - 2341
T_x[229] = T_x[229] + 794
T_x[237] = T_x[237] + 336
T_x[249] = T_x[249] + 791
T_x[258] = T_x[258] - 731
T_x[263] = T_x[263] + 669
T_x[275] = T_x[275] - 485
T_x[286] = T_x[286] - 236
T_x[298] = T_x[298] + 664
'''
plt.xlabel('Frequency(MHz)')
plt.ylabel('Temp(K)')
plt.xlim([50,100])
plt.plot(freq,T_x)
plt.plot(freq,T_y)
a = freq
b = np.array(T_x)
RFI = np.zeros_like(T_y)
print ("X values are:", b)
print ("Y values are:", a)
np.save('C:/Users/msonawan/Documents/Data/plot_1',T_x)
# Out:
# X values are: [4826.42       4786.30032787 4746.64600115 4707.45010313 4668.70584231
#  4630.40654979 4592.5456766  4555.11679122 4518.11357705 4481.52983003
#  4445.35945625 4409.59646964 4374.23498977 4339.26923961 4635.52659255
#  4270.50232449 4236.69010351 4203.25149612 4170.18121122 4137.474049
#  4105.12489908 4073.12873872 4041.48063104 4010.17572329 3979.20924514
#  4165.3737069  3918.27289876 3888.29388743 3858.63501641 3829.29190358
#  3800.26023991 3771.53578803 3743.1143808  3714.99191998 3687.16437486
#  3659.62778094 3632.37823869 3605.41191224 3578.7250282  3552.31387445
#  3526.17479895 3500.3042086  3474.69856816 3449.35439908 3424.26827849
#  3399.43683811 3374.85676326 3350.52479182 3326.43771327 3302.59236772
#  3278.98564496 3255.61448357 3232.47586999 3209.56683764 3186.88446608
#  3164.42588011 3142.18824904 3120.16878576 3098.36474605 3076.77342774
#  3445.47519103 3034.21835251 3013.24939485 2992.48275569 2971.91593214
# ...

# %%
RFI[9] = RFI[9] +569
RFI[18] = RFI[18] - 100
RFI[25] = RFI[25] - 200
RFI[35] = RFI[35] + 300
RFI[55] = RFI[55] + 550
RFI[62] = RFI[62] + 150
RFI[75] = RFI[75] + 250
RFI[84] = RFI[84] + 350
RFI[93] = RFI[93] - 250
RFI[110] = RFI[110] + 600
RFI[126] = RFI[126] + 275
RFI[140] = RFI[140] - 450
RFI[151] = RFI[151] - 468
RFI[169] = RFI[169] + 467
RFI[172] = RFI[172] + 837
RFI[189] = RFI[189] - 446
RFI[195] = RFI[195] + 761
RFI[203] = RFI[203] - 479
RFI[216] = RFI[216] - 2341
RFI[229] = RFI[229] + 794
RFI[237] = RFI[237] + 336
RFI[249] = RFI[249] + 791
RFI[258] = RFI[258] - 731
RFI[263] = RFI[263] + 669
RFI[275] = RFI[275] - 485
RFI[286] = RFI[286] - 236
RFI[298] = RFI[298] + 664
points = np.array([9,18,25,35,55,62,75,84,93,110,126,140,151,169,172,189,195,203,216,229,237,249,258,263,275,286,298])
print(points)
# Out:
# [  9  18  25  35  55  62  75  84  93 110 126 140 151 169 172 189 195 203
#  216 229 237 249 258 263 275 286 298]

# %%
plt.plot(freq,RFI)

# %%
np.savez('C:/Users/msonawan/Documents/Data/Data_file_1',spectra=T_y,RFI_channels=points,RFI_amps=RFI)
